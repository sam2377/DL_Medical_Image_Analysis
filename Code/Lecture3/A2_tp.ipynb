# %% [markdown]
# # Assignment 2
#
# * In this assignment, we will train a CNN classifier with brain tumor dataset.

# %% [markdown]
# # Environment
# * Use the following lines to import any needed libraries:

# %%
import warnings
warnings.filterwarnings('ignore')

from glob import glob
import os
import pandas as pd
import numpy as np
from numpy.random import seed
from numpy import expand_dims

import cv2
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

from IPython.display import Image, display
from PIL import Image

import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

# %% [markdown]
# # Data
# * Dataset ref: https://www.kaggle.com/masoudnickparvar/brain-tumor-mri-dataset
# * Load the datasets and display.
# * There are 4types of images in this dataset, including 3 types of images with brain tumors(glioma, meningioma, notumor, pituitary) and 1 type of images without brain tumor.

# %%
# In this block, please 

# 1. load images from 2 folders(Training, Testing)
#     Structure:
#         For Training data:
#             ----brain_tumor
#                 ----Training
#                     ----glioma
#                     ----meningioma
#                     ----notumor
#                     ----pituitary
#         For Testing data:
#             ----brain_tumor
#                 ----Testing
#                     ----glioma
#                     ----meningioma
#                     ----notumor
#                     ----pituitary    

# 2. Set image labels to corresponding class(variable type: int)
#     Type          Class
#     ===================
#     glioma        0
#     meningioma    1
#     notumor       2
#     pituitary     3
    
# 3. Get train images, test image, train labels, test labels in this block

# 4. Print the image number for each class in training and testing dataset.


img_width, img_height = 256, 256



print('Train glioma:', )
print('Train meningioma:', )
print('Train notumor:', )
print('Train pituitary:', )
print('Test glioma:', )
print('Test meningioma:', )
print('Test notumor:', )
print('Test pituitary:', )
# Out:
# Train glioma: 1321
# Train meningioma: 1339
# Train notumor: 1595
# Train pituitary: 1457
# Test glioma: 300
# Test meningioma: 306
# Test notumor: 405
# Test pituitary: 300

# %%
# Display 9 images in dataset, and show corresponding labels
plt.figure(figsize=(10, 10))

plt.show()

# %% [markdown]
# # Splitting dataset

# %%
num_classes = 4
# Convert training and testing labels to one hot encoding 


# Split testing dataset into validation dataset and testing dataset.(validation:testing =  1:1)
# Out:
# (5712, 655, 656)

# %% [markdown]
# # Define the model

# %%
# Build model using Keras.
# use keras Sequential. Usage: https://keras.io/api/models/sequential/

# %%
# Show model  
# Use summary
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 32)      320
# _________________________________________________________________
# activation (Activation)      (None, 254, 254, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 32)      9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 125, 125, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 60, 60, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 57600)             0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 230404
# _________________________________________________________________
# activation_3 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 258,468
# Trainable params: 258,468
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Display feature maps

# %%
# Display at least 2 different level ffeature maps 
# Usage: https://keras.io/guides/sequential_model/
# Out:
# ==================================================
# ==================================================
# ==================================================

# %% [markdown]
# # Model fitting

# %%
# Use Keras ImageDataGenerator to rescale dataset
# Usage: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerat
# function: "ImageDataGenerator", "flow"




# model fitting (use  function "fit_generator")
# Out:
# Epoch 1/30
# 571/571 [==============================] - 7s 10ms/step - loss: 0.5799 - accuracy: 0.7774 - val_loss: 0.5015 - val_accuracy: 0.8185
# Epoch 2/30
# 571/571 [==============================] - 6s 11ms/step - loss: 0.2914 - accuracy: 0.8944 - val_loss: 0.2937 - val_accuracy: 0.8908
# Epoch 3/30
# 571/571 [==============================] - 6s 10ms/step - loss: 0.1556 - accuracy: 0.9495 - val_loss: 0.2237 - val_accuracy: 0.9277
# Epoch 4/30
# 571/571 [==============================] - 6s 10ms/step - loss: 0.0787 - accuracy: 0.9728 - val_loss: 0.1477 - val_accuracy: 0.9523
# Epoch 5/30
# 571/571 [==============================] - 6s 10ms/step - loss: 0.0500 - accuracy: 0.9833 - val_loss: 0.1650 - val_accuracy: 0.9477
# Epoch 6/30
# 571/571 [==============================] - 6s 10ms/step - loss: 0.0397 - accuracy: 0.9879 - val_loss: 0.2086 - val_accuracy: 0.9508
# Epoch 7/30
# 571/571 [==============================] - 6s 10ms/step - loss: 0.0291 - accuracy: 0.9898 - val_loss: 0.3368 - val_accuracy: 0.9308
# Epoch 8/30
# 571/571 [==============================] - 6s 11ms/step - loss: 0.0240 - accuracy: 0.9926 - val_loss: 0.2283 - val_accuracy: 0.9415
# Epoch 9/30
# 571/571 [==============================] - 6s 10ms/step - loss: 0.0261 - accuracy: 0.9919 - val_loss: 0.3622 - val_accuracy: 0.9385
# Epoch 10/30
# 571/571 [==============================] - 6s 10ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.2804 - val_accuracy: 0.9569
# Epoch 11/30
# 571/571 [==============================] - 6s 10ms/step - loss: 0.0329 - accuracy: 0.9902 - val_loss: 0.1948 - val_accuracy: 0.9585
# Epoch 12/30
# 571/571 [==============================] - 6s 11ms/step - loss: 0.0289 - accuracy: 0.9902 - val_loss: 0.1931 - val_accuracy: 0.9600
# Epoch 13/30
# 571/571 [==============================] - 6s 10ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.2844 - val_accuracy: 0.9569
# Epoch 14/30
# 571/571 [==============================] - 6s 10ms/step - loss: 3.4510e-04 - accuracy: 1.0000 - val_loss: 0.2740 - val_accuracy: 0.9615
# Epoch 15/30
# 571/571 [==============================] - 6s 11ms/step - loss: 7.0394e-05 - accuracy: 1.0000 - val_loss: 0.2723 - val_accuracy: 0.9662
# Epoch 16/30
# 571/571 [==============================] - 6s 10ms/step - loss: 3.5616e-05 - accuracy: 1.0000 - val_loss: 0.2790 - val_accuracy: 0.9646
# Epoch 17/30
# 571/571 [==============================] - 6s 10ms/step - loss: 2.6149e-05 - accuracy: 1.0000 - val_loss: 0.2824 - val_accuracy: 0.9662
# Epoch 18/30
# 571/571 [==============================] - 6s 10ms/step - loss: 1.9371e-05 - accuracy: 1.0000 - val_loss: 0.2862 - val_accuracy: 0.9662
# Epoch 19/30
# 571/571 [==============================] - 6s 10ms/step - loss: 1.4456e-05 - accuracy: 1.0000 - val_loss: 0.2876 - val_accuracy: 0.9662
# Epoch 20/30
# 571/571 [==============================] - 6s 10ms/step - loss: 1.0806e-05 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.9662
# Epoch 21/30
# 571/571 [==============================] - 6s 10ms/step - loss: 7.9707e-06 - accuracy: 1.0000 - val_loss: 0.2954 - val_accuracy: 0.9662
# Epoch 22/30
# 571/571 [==============================] - 5s 9ms/step - loss: 5.9308e-06 - accuracy: 1.0000 - val_loss: 0.2900 - val_accuracy: 0.9677
# Epoch 23/30
# 571/571 [==============================] - 6s 11ms/step - loss: 4.3493e-06 - accuracy: 1.0000 - val_loss: 0.2740 - val_accuracy: 0.9677
# Epoch 24/30
# 571/571 [==============================] - 5s 10ms/step - loss: 3.2703e-06 - accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.9662
# Epoch 25/30
# 571/571 [==============================] - 5s 9ms/step - loss: 2.4211e-06 - accuracy: 1.0000 - val_loss: 0.3158 - val_accuracy: 0.9662
# Epoch 26/30
# 571/571 [==============================] - 6s 10ms/step - loss: 1.7428e-06 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 0.9692
# Epoch 27/30
# 571/571 [==============================] - 6s 10ms/step - loss: 1.2906e-06 - accuracy: 1.0000 - val_loss: 0.3269 - val_accuracy: 0.9662
# Epoch 28/30
# 571/571 [==============================] - 6s 11ms/step - loss: 9.5326e-07 - accuracy: 1.0000 - val_loss: 0.3206 - val_accuracy: 0.9677
# Epoch 29/30
# 571/571 [==============================] - 6s 10ms/step - loss: 6.8466e-07 - accuracy: 1.0000 - val_loss: 0.3366 - val_accuracy: 0.9677
# Epoch 30/30
# 571/571 [==============================] - 6s 11ms/step - loss: 5.0665e-07 - accuracy: 1.0000 - val_loss: 0.3275 - val_accuracy: 0.9692

# %% [markdown]
# # Plot training & validation history
# * 2 Figures: loss and accuaracy

# %%
# Plot training & validation accuracy values

# Plot training & validation loss values

# %% [markdown]
# # Predict and show accuracy
# * 2 Figures: loss and accuaracy

# %%
print("Accuracy", , "%")
# Out:
# 0.9573170731707317

# %% [markdown]
# #  Grad-cam

# %% [markdown]
# * select one images from test dataset and show its heatmap
# * Usage: https://keras.io/examples/vision/grad_cam/

# %%
# https://keras.io/examples/vision/grad_cam/
# https://machinelearningmastery.com/how-to-visualize-filters-and-feature-maps-in-convolutional-neural-networks/
# https://keras.io/guides/sequential_model/

# %% [markdown]
# * Superimposed  heatmap  on original image and display it.

# %%
def save_and_display_gradcam(img, heatmap, cam_path="cam.jpg", alpha=0.4):

    # Use jet colormap to colorize heatmap

    # Use RGB values of the colormap

    # Create an image with RGB colorized heatmap

    # Superimpose the heatmap on original image

    # Display Grad CAM

# %%
# Display 4 image with different classes in test dataset, show their labels and superimposed image
# Out:
# glioma
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F58A830F610>
# pituitary
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F58A8281190>
# notumor
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F58A820AC70>
# meningioma
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F58A813B6A0>

# %% [markdown]
# # Display confusion_matrix

# %%
# Sklearn: confusion_matrix
# Out:
# Text(0.5, 51.0, 'predicted label')
