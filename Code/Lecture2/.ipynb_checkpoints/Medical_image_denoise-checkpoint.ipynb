# %%
import os
import re
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import cv2
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam

# %%
def show_image(array):
    n = 10
    indices = np.random.randint(len(array), size=n)
    images = array[indices, :]
    fig, axes = plt.subplots(2, 5, figsize=(15,5))
    for i in range(2):
        for j in range(5):
            image = images[i*5+j, :, :]
            axes[i, j].set_title("Index = {}".format(indices[i*5+j]))
            axes[i, j].axis("off")
            axes[i, j].imshow(images[i*5+j].reshape(array.shape[1], array.shape[2]), cmap='gray')
    plt.show()

# %%
def read_pgm(filename):
    """Return image data from a raw PGM file as numpy array.
    Format specification: http://netpbm.sourceforge.net/doc/pgm.html
    https://zh.wikipedia.org/wiki/PBM%E6%A0%BC%E5%BC%8F
    """
    with open(filename, 'rb') as f:
        buffer = f.read()
    try:
        header, width, height, maxval = re.search(
            b"(^P5\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n]\s)*)", buffer).groups()
#         print('Header:{}\nWidth:{}\nHeight:{}\nMaxval:{}'.format(header, width, height, maxval))
#         print('len {}'.format(len(header)))
    except AttributeError:
        raise ValueError("Not a raw PGM file: '%s'" % filename)
    return np.frombuffer(buffer,
                            dtype='u1',
                            count=int(width) * int(height),
                            offset=len(header)
                            ).reshape((int(height), int(width)))

# %%
def read_mini_mias():
    images_tensor = np.zeros((322, 1024, 1024))
    i = 0
    for dirName, subdirList, fileList in os.walk("data/all-mias/"):
        for fname in fileList:
            if fname.endswith(".pgm"):
                images_tensor[i] = read_pgm("data/all-mias/" + fname)
                i += 1
    return images_tensor

# %%
def read_dental(folder="./data/dental/"):
    images = []
    for filename in sorted(os.listdir(folder), key=lambda x : int(x.split('.')[0])):
#         print(os.path.join(folder, filename))
        img = cv2.imread(os.path.join(folder, filename), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            images.append(img)
    return np.array(images)

# %%
def read_dx(folder="data/DX/"):
    images = []
    for filename in sorted(os.listdir(folder), key=lambda x : int(x.split('.')[0])):
        img = cv2.imread(os.path.join(folder, filename), cv2.IMREAD_GRAYSCALE)
#         print(os.path.join(folder, filename))
        if img is not None:
            images.append(img)
    return np.array(images)

# %%
def load_datasets(img_width=64, img_height=64):
    # Read mias dataset
    raw_mias = read_mini_mias()
    mias_images = np.zeros((raw_mias.shape[0], img_width, img_height))
    for i in range(raw_mias.shape[0]):
        mias_images[i] = cv2.resize(raw_mias[i], dsize=(img_width, img_height),
                                    interpolation=cv2.INTER_CUBIC)
    # Read dental dataset
    # Digital Dental Periapical X-Ray Database for Caries Screening
    raw_dental = read_dental()  
    dental_images = np.zeros((raw_dental.shape[0], img_width, img_width))
    for i in range(raw_dental.shape[0]):
        dental_images[i] = cv2.resize(raw_dental[i], dsize=(img_width, img_height),
                                      interpolation=cv2.INTER_CUBIC)
    # Read DX dataset
    # A benchmark for comparison of dental radiography analysis algorithms
    raw_dx = read_dx()
    dx_images = np.zeros((raw_dx.shape[0], img_width, img_width))
    for i in range(raw_dx.shape[0]):
        dx_images[i] = cv2.resize(raw_dx[i], dsize=(img_width, img_height),
                                  interpolation=cv2.INTER_CUBIC)
    
    return mias_images, dx_images, dental_images

# %%
def train_test_split(mias_images, dx_images, dental_images, train_split=0.9, img_height=64, img_width=64):
    imageset_train = mias_images[:int(mias_images.shape[0] * train_split)]
    imageset_train = np.append(imageset_train, dx_images[:int(dx_images.shape[0] * train_split)], axis=0)
#     imageset_train = np.append(imageset_train, dental_images[:int(dental_images.shape[0] * train_split)], axis=0)
    
    imageset_test = mias_images[int(mias_images.shape[0] * train_split):]
    imageset_test = np.append(imageset_test, dx_images[int(dx_images.shape[0] * train_split):], axis=0)
#     imageset_test = np.append(imageset_test, dental_images[int(dental_images.shape[0] * train_split):], axis=0)

    np.random.shuffle(imageset_train)
    
    imageset_train = imageset_train.reshape(imageset_train.shape[0], img_height, img_width, 1)
    imageset_test = imageset_test.reshape(imageset_test.shape[0], img_height, img_width, 1)
    
    return imageset_train, imageset_test

# %%
def add_noise(array):
    """
    Adds random noise to each image in the supplied array.
    """

    noise_factor = 0.4
    noisy_array = array + noise_factor * np.random.normal(
        loc=0.0, scale=1.0, size=array.shape
    )

    return np.clip(noisy_array, 0.0, 1.0)

# %%
def build_model(img_width=64, img_height=64):
    autoencoder = keras.Sequential()
    # Encoder
    autoencoder.add(keras.Input(shape=(img_width, img_height, 1)))
    autoencoder.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    autoencoder.add(layers.MaxPooling2D((2, 2), padding='same'))
    autoencoder.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    autoencoder.add(layers.MaxPooling2D((2, 2), padding='same'))
    # Decoder
    autoencoder.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    autoencoder.add(layers.UpSampling2D((2, 2)))
    autoencoder.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    autoencoder.add(layers.UpSampling2D((2, 2)))
    autoencoder.add(layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same'))
    autoencoder.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    autoencoder.summary()
    return autoencoder

# %%
img_width = 64
img_height = 64
mias_images, dx_images, dental_images = load_datasets(img_width, img_height)
print('MIAS dataset')
show_image(mias_images)
print('Dental X-ray dataset')
show_image(dx_images)
print('Dental Periapical X-Ray dataset')
show_image(dental_images)
# Out:
# MIAS dataset
# Dental X-ray dataset
# Dental Periapical X-Ray dataset

# %%
mias_images.shape
# Out:
# (322, 64, 64)

# %%
dx_images.shape
# Out:
# (400, 64, 64)

# %%
dental_images.shape
# Out:
# (120, 64, 64)

# %%
input_train, input_test = train_test_split(mias_images, dx_images, dental_images, 0.9, 64, 64)

# %%
show_image(input_train)

# %%
# Scale images to the [0, 1] range
input_train = input_train.astype("float32") / 255
input_test = input_test.astype("float32") / 255

# %%
noisy_train = add_noise(input_train)
noisy_test = add_noise(input_test)

# %%
show_image(noisy_train)

# %%
cnn_denoiser = build_model(64, 64)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        73792
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 1)         577
# =================================================================
# Total params: 296,449
# Trainable params: 296,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn_denoiser.fit(
    noisy_train,
    input_train,
    epochs = 50,
    batch_size = 10,
    shuffle = True,
    validation_split = 0.1,
    verbose = 1
)
# Out:
# Epoch 1/50
# 59/59 [==============================] - 3s 15ms/step - loss: 0.5465 - accuracy: 0.2140 - val_loss: 0.4335 - val_accuracy: 0.2109
# Epoch 2/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4266 - accuracy: 0.2139 - val_loss: 0.4201 - val_accuracy: 0.2111
# Epoch 3/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4162 - accuracy: 0.2196 - val_loss: 0.4152 - val_accuracy: 0.2115
# Epoch 4/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4075 - accuracy: 0.2252 - val_loss: 0.4129 - val_accuracy: 0.2121
# Epoch 5/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4116 - accuracy: 0.2176 - val_loss: 0.4107 - val_accuracy: 0.2124
# Epoch 6/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4063 - accuracy: 0.2217 - val_loss: 0.4100 - val_accuracy: 0.2125
# Epoch 7/50
# 59/59 [==============================] - 0s 7ms/step - loss: 0.4052 - accuracy: 0.2241 - val_loss: 0.4082 - val_accuracy: 0.2130
# Epoch 8/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4006 - accuracy: 0.2297 - val_loss: 0.4094 - val_accuracy: 0.2129
# Epoch 9/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4046 - accuracy: 0.2232 - val_loss: 0.4070 - val_accuracy: 0.2131
# Epoch 10/50
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3969 - accuracy: 0.2345 - val_loss: 0.4081 - val_accuracy: 0.2130
# Epoch 11/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4070 - accuracy: 0.2189 - val_loss: 0.4075 - val_accuracy: 0.2131
# Epoch 12/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.3963 - accuracy: 0.2288 - val_loss: 0.4067 - val_accuracy: 0.2130
# Epoch 13/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4103 - accuracy: 0.2093 - val_loss: 0.4058 - val_accuracy: 0.2130
# Epoch 14/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4164 - accuracy: 0.1989 - val_loss: 0.4051 - val_accuracy: 0.2131
# Epoch 15/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4008 - accuracy: 0.2197 - val_loss: 0.4050 - val_accuracy: 0.2131
# Epoch 16/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4001 - accuracy: 0.2230 - val_loss: 0.4049 - val_accuracy: 0.2131
# Epoch 17/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4058 - accuracy: 0.2155 - val_loss: 0.4045 - val_accuracy: 0.2131
# Epoch 18/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4026 - accuracy: 0.2189 - val_loss: 0.4045 - val_accuracy: 0.2131
# Epoch 19/50
# 59/59 [==============================] - 0s 7ms/step - loss: 0.4029 - accuracy: 0.2204 - val_loss: 0.4043 - val_accuracy: 0.2131
# Epoch 20/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4050 - accuracy: 0.2133 - val_loss: 0.4057 - val_accuracy: 0.2132
# Epoch 21/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4045 - accuracy: 0.2156 - val_loss: 0.4046 - val_accuracy: 0.2131
# Epoch 22/50
# 59/59 [==============================] - 0s 8ms/step - loss: 0.3939 - accuracy: 0.2315 - val_loss: 0.4040 - val_accuracy: 0.2131
# Epoch 23/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4016 - accuracy: 0.2199 - val_loss: 0.4037 - val_accuracy: 0.2131
# Epoch 24/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.3981 - accuracy: 0.2269 - val_loss: 0.4038 - val_accuracy: 0.2131
# Epoch 25/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4085 - accuracy: 0.2073 - val_loss: 0.4035 - val_accuracy: 0.2132
# Epoch 26/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3966 - accuracy: 0.2277 - val_loss: 0.4070 - val_accuracy: 0.2132
# Epoch 27/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3975 - accuracy: 0.2253 - val_loss: 0.4035 - val_accuracy: 0.2132
# Epoch 28/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4024 - accuracy: 0.2206 - val_loss: 0.4037 - val_accuracy: 0.2131
# Epoch 29/50
# 59/59 [==============================] - 0s 7ms/step - loss: 0.4015 - accuracy: 0.2158 - val_loss: 0.4033 - val_accuracy: 0.2132
# Epoch 30/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3987 - accuracy: 0.2231 - val_loss: 0.4031 - val_accuracy: 0.2132
# Epoch 31/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4007 - accuracy: 0.2141 - val_loss: 0.4036 - val_accuracy: 0.2132
# Epoch 32/50
# 59/59 [==============================] - 1s 9ms/step - loss: 0.3953 - accuracy: 0.2269 - val_loss: 0.4028 - val_accuracy: 0.2132
# Epoch 33/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4055 - accuracy: 0.2106 - val_loss: 0.4033 - val_accuracy: 0.2132
# Epoch 34/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4027 - accuracy: 0.2190 - val_loss: 0.4039 - val_accuracy: 0.2132
# Epoch 35/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3918 - accuracy: 0.2367 - val_loss: 0.4028 - val_accuracy: 0.2132
# Epoch 36/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3923 - accuracy: 0.2319 - val_loss: 0.4026 - val_accuracy: 0.2132
# Epoch 37/50
# 59/59 [==============================] - 0s 7ms/step - loss: 0.4078 - accuracy: 0.2043 - val_loss: 0.4025 - val_accuracy: 0.2132
# Epoch 38/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.3996 - accuracy: 0.2200 - val_loss: 0.4038 - val_accuracy: 0.2132
# Epoch 39/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3984 - accuracy: 0.2220 - val_loss: 0.4035 - val_accuracy: 0.2132
# Epoch 40/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4078 - accuracy: 0.2078 - val_loss: 0.4035 - val_accuracy: 0.2132
# Epoch 41/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.3939 - accuracy: 0.2270 - val_loss: 0.4024 - val_accuracy: 0.2132
# Epoch 42/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4035 - accuracy: 0.2109 - val_loss: 0.4022 - val_accuracy: 0.2132
# Epoch 43/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4001 - accuracy: 0.2201 - val_loss: 0.4024 - val_accuracy: 0.2132
# Epoch 44/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.3983 - accuracy: 0.2215 - val_loss: 0.4025 - val_accuracy: 0.2132
# Epoch 45/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.3983 - accuracy: 0.2214 - val_loss: 0.4025 - val_accuracy: 0.2132
# Epoch 46/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3923 - accuracy: 0.2314 - val_loss: 0.4021 - val_accuracy: 0.2132
# Epoch 47/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.3986 - accuracy: 0.2187 - val_loss: 0.4026 - val_accuracy: 0.2132
# Epoch 48/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.3955 - accuracy: 0.2212 - val_loss: 0.4022 - val_accuracy: 0.2132
# Epoch 49/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3969 - accuracy: 0.2252 - val_loss: 0.4021 - val_accuracy: 0.2132
# Epoch 50/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.3947 - accuracy: 0.2216 - val_loss: 0.4024 - val_accuracy: 0.2132

# %%
samples = noisy_test[:]

# %%
denoised_images = cnn_denoiser.predict(samples)

# %%
show_image(noisy_test)

# %%
show_image(denoised_images)
